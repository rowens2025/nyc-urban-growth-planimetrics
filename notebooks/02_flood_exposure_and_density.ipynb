# %%
import geopandas as gpd
import pandas as pd
import os

DATA_RAW = os.path.join("..", "data", "raw")
DATA_PROCESSED = os.path.join("..", "data", "processed")

CRS_NYC = 2263

# %%
buildings = gpd.read_parquet(
    os.path.join(DATA_PROCESSED, "building_current_2263.parquet")
)

stormwater = gpd.read_parquet(
    os.path.join(DATA_PROCESSED, "stormwater_2263.parquet")
)

nta = gpd.read_file(
    f"zip://{os.path.join(DATA_RAW, 'nta', 'nyc_nta_2020.zip')}"
).to_crs(CRS_NYC)

nta_density = pd.read_parquet(
    os.path.join(DATA_PROCESSED, "nta_construction_density.parquet")
)

buildings.crs, stormwater.crs, nta.crs
# Out:
# (<Projected CRS: EPSG:2263>
#  Name: NAD83 / New York Long Island (ftUS)
#  Axis Info [cartesian]:
#  - X[east]: Easting (US survey foot)
#  - Y[north]: Northing (US survey foot)
#  Area of Use:
#  - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
#  - bounds: (-74.26, 40.47, -71.8, 41.3)
#  Coordinate Operation:
#  - name: SPCS83 New York Long Island zone (US survey foot)
#  - method: Lambert Conic Conformal (2SP)
#  Datum: North American Datum 1983
#  - Ellipsoid: GRS 1980
#  - Prime Meridian: Greenwich,
#  <Projected CRS: EPSG:2263>
#  Name: NAD83 / New York Long Island (ftUS)
#  Axis Info [cartesian]:
#  - X[east]: Easting (US survey foot)
#  - Y[north]: Northing (US survey foot)
#  Area of Use:
#  - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
#  - bounds: (-74.26, 40.47, -71.8, 41.3)
#  Coordinate Operation:
#  - name: SPCS83 New York Long Island zone (US survey foot)
#  - method: Lambert Conic Conformal (2SP)
#  Datum: North American Datum 1983
#  - Ellipsoid: GRS 1980
#  - Prime Meridian: Greenwich,
#  <Projected CRS: EPSG:2263>
#  Name: NAD83 / New York Long Island (ftUS)
#  Axis Info [cartesian]:
#  - X[east]: Easting (US survey foot)
#  - Y[north]: Northing (US survey foot)
#  Area of Use:
#  - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
#  - bounds: (-74.26, 40.47, -71.8, 41.3)
#  Coordinate Operation:
#  - name: SPCS83 New York Long Island zone (US survey foot)
#  - method: Lambert Conic Conformal (2SP)
#  Datum: North American Datum 1983
#  - Ellipsoid: GRS 1980
#  - Prime Meridian: Greenwich)

# %%
stormwater_union = stormwater.dissolve(
    by="Flooding_Category", as_index=False
)

stormwater_flooded = stormwater_union.copy()

# %%
flood_geom = stormwater_flooded.geometry.union_all()

minx, miny, maxx, maxy = flood_geom.bounds
buildings_bb = buildings.cx[minx:maxx, miny:maxy]

print("Buildings total:", len(buildings))
print("Buildings in flood bbox:", len(buildings_bb))


buildings_bb = buildings_bb.copy()
buildings_bb.loc[:, "is_flooded"] = buildings_bb.geometry.intersects(flood_geom)



buildings["is_flooded"] = False
buildings.loc[buildings_bb.index, "is_flooded"] = buildings_bb["is_flooded"]
# Out:
# Buildings total: 1082999
# Buildings in flood bbox: 1080650

# %%
buildings["is_flooded"].value_counts()
# Out:
# is_flooded
# False    1061485
# True       21514
# Name: count, dtype: int64

# %%
buildings["is_flooded"].mean()
# Out:
# np.float64(0.019865207631770666)

# %%
buildings.head(10)
# Out:
#    name        bin  doitt_id  shape_area    base_bbl  objectid  constructi  \
# 0  None  4451699.0  321944.0  177.746094  4075320028  507357.0      1950.0
# 1  None  4558952.0  255026.0   34.742188  4105630045  137879.0      1930.0
# 2  None  3176483.0  759005.0  180.890625  3066450044  982953.0      1915.0
# 3  None  3393369.0  949392.0  106.035156  3038010128  244121.0      1997.0
# 4  None  2019299.0  353927.0  217.175781  2033800084  229537.0      1910.0
# 5  None  5052578.0  281098.0  240.582031  5036360058  246429.0      1960.0
# 6  None  3083803.0  419689.0   98.660156  3037200028  808886.0      1901.0
# 7  None  3100941.0  533049.0  588.093750  3046410004  370632.0      1931.0
# 8  None  2117607.0  458160.0  102.941406  2027640025   80512.0         NaN
# 9  None  5007740.0  649423.0  232.261719  5002870016  232182.0      1955.0
#
#    feature_co       geom_sourc  ground_ele  height_roo date_last_  \
# 0      2100.0   Other (Manual)        93.0   27.000000 2017-08-22
# 1      5110.0  Photogrammetric        72.0   13.060000 2017-08-17
# 2      2100.0  Photogrammetric        18.0   36.761589 2017-08-22
# 3      2100.0  Photogrammetric        32.0   21.950000 2017-08-22
# 4      2100.0  Photogrammetric       197.0   33.490000 2017-08-22
# 5      2100.0  Photogrammetric        44.0   21.130000 2017-08-22
# 6      2100.0  Photogrammetric        44.0   30.110000 2017-08-22
# 7      2100.0  Photogrammetric        34.0   14.310000 2017-08-22
# 8      2100.0   Other (Manual)        25.0   11.000000 2017-08-10
# 9      2100.0  Photogrammetric       220.0   17.960000 2017-08-22
#
#      time_last_   last_statu  mappluto_b  shape_leng  \
# 0  19:18:38.000  Constructed  4075327501   59.004939
# 1  16:20:43.000  Constructed  4105630045   24.548387
# 2  15:37:34.000  Constructed  3066450044   61.475641
# 3  15:31:10.000  Constructed  3038010128   43.732572
# 4  18:57:18.000  Constructed  2033800084   63.268290
# 5  18:56:39.000  Constructed  5036360058   69.030911
# 6  15:51:01.000  Constructed  3037200028   43.248158
# 7  15:46:44.000  Constructed  3046410004  107.406265
# 8  15:05:25.000  Constructed  2027640025   47.428753
# 9  17:36:42.000  Constructed  5002870016   63.023228
#
#                                             geometry  geom_area_sqft  \
# 0  POLYGON ((1052359.953 214149.188, 1052400.668 ...     1096.759439
# 1  POLYGON ((1052764.922 201306.381, 1052748.182 ...      214.631781
# 2  POLYGON ((988769.316 159090.345, 988746.041 15...     1121.202926
# 3  POLYGON ((1012469.24 181742.107, 1012446.631 1...      656.015069
# 4  POLYGON ((1020199.824 267310.273, 1020201.035 ...     1334.183950
# 5  POLYGON ((952462.054 148588.137, 952441.334 14...     1492.459367
# 6  POLYGON ((1013026.308 184325.289, 1012989.42 1...      610.216125
# 7  POLYGON ((1004596.249 178502.966, 1004590.431 ...     3639.355961
# 8  POLYGON ((1016582.739 236282.258, 1016574.046 ...      634.043292
# 9  POLYGON ((954298.282 166992.865, 954260.635 16...     1438.693395
#
#    is_flooded
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False

# %%
buildings[buildings["is_flooded"]].head(10)
# Out:
#      name        bin   doitt_id   shape_area    base_bbl   objectid  \
# 31   None  5053642.0    96057.0   238.015625  5037000017   613411.0
# 37   None  1091774.0  1300615.0   433.242188  1003930059  1087553.0
# 54   None  4006916.0   170637.0  1345.359375  4005760036   844649.0
# 73   None  3173017.0   460535.0   323.882812  3065700074   738209.0
# 206  None  4019979.0   764256.0   128.875000  4008880014  1006242.0
# 277  None  5095461.0   310122.0    99.136719  5036730014   767563.0
# 341  None  4286890.0   527208.0   245.324219  4134850036   419769.0
# 353  None  4438762.0   312200.0  1186.410156  4101760012   573208.0
# 434  None  5060553.0   335781.0   337.937500  5044350047   901665.0
# 444  None  3327258.0   487208.0   118.261719  3027340101    36970.0
#
#      constructi  feature_co       geom_sourc  ground_ele  height_roo  \
# 31       1935.0      2100.0  Photogrammetric         9.0   20.880000
# 37       2023.0      2100.0   Other (Manual)        12.0   75.000000
# 54       1963.0      2100.0  Photogrammetric        31.0   63.010000
# 73       1930.0      2100.0  Photogrammetric        31.0   32.080000
# 206      1901.0      2100.0  Photogrammetric        26.0   12.170000
# 277      1989.0      2100.0  Photogrammetric         4.0   29.210000
# 341      1955.0      2100.0  Photogrammetric        13.0   17.507202
# 353      1961.0      2100.0  Photogrammetric        29.0   19.640000
# 434      1970.0      2100.0  Photogrammetric        38.0   21.700000
# 444      1928.0      2100.0  Photogrammetric        11.0   33.580000
#
#     date_last_    time_last_   last_statu  mappluto_b  shape_leng  \
# 31  2017-08-22  17:30:13.000  Constructed  5037000017   63.755680
# 37  2023-09-14  18:08:49.000  Constructed  1003930059   83.400610
# 54  2017-08-22  17:40:43.000  Constructed  4005760036  172.632505
# 73  2017-08-22  15:29:18.000  Constructed  3065700074   91.249948
# 206 2017-08-22  19:24:03.000  Constructed  4008880014   50.737649
# 277 2017-08-22  18:13:55.000  Constructed  5036730014   39.949946
# 341 2017-08-22  17:34:14.000  Constructed  4134850036   70.854284
# 353 2017-08-22  18:12:01.000  Constructed  4101760012  146.146700
# 434 2017-08-22  18:42:44.000  Constructed  5044350047   77.112411
# 444 2024-03-21  14:43:30.000  Constructed  3027340101   43.825604
#
#                                               geometry  geom_area_sqft  \
# 31   POLYGON ((955341.932 148874.892, 955363.559 14...     1476.515164
# 37   POLYGON ((990006.187 204026.649, 989963.428 20...     2675.456081
# 54   POLYGON ((1005361.62 219044.252, 1005348.138 2...     8298.019779
# 73   POLYGON ((993376.142 163764.302, 993303.032 16...     2006.774427
# 206  POLYGON ((1004791.433 221618.283, 1004764.732 ...      794.736908
# 277  POLYGON ((956856.98 150323.871, 956875.16 1503...      614.878858
# 341  POLYGON ((1053227.737 180422.348, 1053221.666 ...     1517.957736
# 353  POLYGON ((1043407.557 193599.092, 1043323.715 ...     7332.990651
# 434  POLYGON ((945075.275 146869.948, 945092.881 14...     2096.721109
# 444  POLYGON ((999162.887 200881.604, 999132.516 20...      730.491551
#
#      is_flooded
# 31         True
# 37         True
# 54         True
# 73         True
# 206        True
# 277        True
# 341        True
# 353        True
# 434        True
# 444        True

# %%
area_col = "geom_area_sqft"


buildings = buildings.copy()

# flooded area by sq ft (if flooded, if not then 0)
buildings["flooded_footprint_sqft"] = buildings[area_col].where(buildings["is_flooded"], 0.0)

buildings[[area_col, "is_flooded", "flooded_footprint_sqft"]].head(10)
# Out:
#    geom_area_sqft  is_flooded  flooded_footprint_sqft
# 0     1096.759439       False                     0.0
# 1      214.631781       False                     0.0
# 2     1121.202926       False                     0.0
# 3      656.015069       False                     0.0
# 4     1334.183950       False                     0.0
# 5     1492.459367       False                     0.0
# 6      610.216125       False                     0.0
# 7     3639.355961       False                     0.0
# 8      634.043292       False                     0.0
# 9     1438.693395       False                     0.0

# %%
nta_density.head(10)
# Out:
#   NTACode                              NTAName  boroname  \
# 0  BK0101                           Greenpoint  Brooklyn
# 1  BK0102                         Williamsburg  Brooklyn
# 2  BK0103                   South Williamsburg  Brooklyn
# 3  BK0104                    East Williamsburg  Brooklyn
# 4  BK0201                     Brooklyn Heights  Brooklyn
# 5  BK0202  Downtown Brooklyn-DUMBO-Boerum Hill  Brooklyn
# 6  BK0203                          Fort Greene  Brooklyn
# 7  BK0204                         Clinton Hill  Brooklyn
# 8  BK0261                   Brooklyn Navy Yard  Brooklyn
# 9  BK0301            Bedford-Stuyvesant (West)  Brooklyn
#
#                                             geometry  nta_area_sqft  \
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xdb\x01...   3.532174e+07
# 1  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x16\x01...   2.885280e+07
# 2  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00f\x00\x0...   1.520896e+07
# 3  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xa8\x02...   5.226747e+07
# 4  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00~\x00\x0...   9.982088e+06
# 5  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00*\x01\x0...   2.373148e+07
# 6  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x90\x00...   1.753369e+07
# 7  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00T\x00\x0...   1.456661e+07
# 8  b'\x01\x06\x00\x00\x00\x02\x00\x00\x00\x01\x03...   1.010687e+07
# 9  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00r\x00\x0...   3.690666e+07
#
#    nta_area_sqmi  building_count  total_footprint_sqft  median_building_sqft  \
# 0       1.266993          5147.0          1.340080e+07           1248.021588
# 1       1.034952          3646.0          1.037733e+07           1334.824761
# 2       0.545546          2294.0          5.418461e+06           1408.694795
# 3       1.874838          4939.0          1.745002e+07           1354.539352
# 4       0.358058          1492.0          3.913004e+06           1358.771123
# 5       0.851250          2000.0          8.258165e+06           1152.637541
# 6       0.628935          2130.0          5.244622e+06            994.499027
# 7       0.522505          2403.0          4.768999e+06            947.440147
# 8       0.362534           133.0          2.373427e+06           3920.259287
# 9       1.323844          7547.0          1.301454e+07            969.488934
#
#    built_area_ratio  buildings_per_sqmi  built_sqft_per_sqmi
# 0          0.379392         4062.373817         1.057685e+07
# 1          0.359665         3522.869432         1.002687e+07
# 2          0.356268         4204.958583         9.932172e+06
# 3          0.333860         2634.361536         9.307485e+06
# 4          0.392003         4166.921140         1.092840e+07
# 5          0.347984         2349.487226         9.701226e+06
# 6          0.299117         3386.680069         8.338900e+06
# 7          0.327392         4598.996563         9.127179e+06
# 8          0.234833          366.861926         6.546766e+06
# 9          0.352634         5700.821880         9.830872e+06

# %%
buildings.head(10)
# Out:
#    name        bin  doitt_id  shape_area    base_bbl  objectid  constructi  \
# 0  None  4451699.0  321944.0  177.746094  4075320028  507357.0      1950.0
# 1  None  4558952.0  255026.0   34.742188  4105630045  137879.0      1930.0
# 2  None  3176483.0  759005.0  180.890625  3066450044  982953.0      1915.0
# 3  None  3393369.0  949392.0  106.035156  3038010128  244121.0      1997.0
# 4  None  2019299.0  353927.0  217.175781  2033800084  229537.0      1910.0
# 5  None  5052578.0  281098.0  240.582031  5036360058  246429.0      1960.0
# 6  None  3083803.0  419689.0   98.660156  3037200028  808886.0      1901.0
# 7  None  3100941.0  533049.0  588.093750  3046410004  370632.0      1931.0
# 8  None  2117607.0  458160.0  102.941406  2027640025   80512.0         NaN
# 9  None  5007740.0  649423.0  232.261719  5002870016  232182.0      1955.0
#
#    feature_co       geom_sourc  ground_ele  height_roo date_last_  \
# 0      2100.0   Other (Manual)        93.0   27.000000 2017-08-22
# 1      5110.0  Photogrammetric        72.0   13.060000 2017-08-17
# 2      2100.0  Photogrammetric        18.0   36.761589 2017-08-22
# 3      2100.0  Photogrammetric        32.0   21.950000 2017-08-22
# 4      2100.0  Photogrammetric       197.0   33.490000 2017-08-22
# 5      2100.0  Photogrammetric        44.0   21.130000 2017-08-22
# 6      2100.0  Photogrammetric        44.0   30.110000 2017-08-22
# 7      2100.0  Photogrammetric        34.0   14.310000 2017-08-22
# 8      2100.0   Other (Manual)        25.0   11.000000 2017-08-10
# 9      2100.0  Photogrammetric       220.0   17.960000 2017-08-22
#
#      time_last_   last_statu  mappluto_b  shape_leng  \
# 0  19:18:38.000  Constructed  4075327501   59.004939
# 1  16:20:43.000  Constructed  4105630045   24.548387
# 2  15:37:34.000  Constructed  3066450044   61.475641
# 3  15:31:10.000  Constructed  3038010128   43.732572
# 4  18:57:18.000  Constructed  2033800084   63.268290
# 5  18:56:39.000  Constructed  5036360058   69.030911
# 6  15:51:01.000  Constructed  3037200028   43.248158
# 7  15:46:44.000  Constructed  3046410004  107.406265
# 8  15:05:25.000  Constructed  2027640025   47.428753
# 9  17:36:42.000  Constructed  5002870016   63.023228
#
#                                             geometry  geom_area_sqft  \
# 0  POLYGON ((1052359.953 214149.188, 1052400.668 ...     1096.759439
# 1  POLYGON ((1052764.922 201306.381, 1052748.182 ...      214.631781
# 2  POLYGON ((988769.316 159090.345, 988746.041 15...     1121.202926
# 3  POLYGON ((1012469.24 181742.107, 1012446.631 1...      656.015069
# 4  POLYGON ((1020199.824 267310.273, 1020201.035 ...     1334.183950
# 5  POLYGON ((952462.054 148588.137, 952441.334 14...     1492.459367
# 6  POLYGON ((1013026.308 184325.289, 1012989.42 1...      610.216125
# 7  POLYGON ((1004596.249 178502.966, 1004590.431 ...     3639.355961
# 8  POLYGON ((1016582.739 236282.258, 1016574.046 ...      634.043292
# 9  POLYGON ((954298.282 166992.865, 954260.635 16...     1438.693395
#
#    is_flooded  flooded_footprint_sqft
# 0       False                     0.0
# 1       False                     0.0
# 2       False                     0.0
# 3       False                     0.0
# 4       False                     0.0
# 5       False                     0.0
# 6       False                     0.0
# 7       False                     0.0
# 8       False                     0.0
# 9       False                     0.0

# %%
nta = nta.rename(columns={"nta2020": "NTACode", "ntaname": "NTAName"})
nta = nta[["NTACode", "NTAName", "boroname", "geometry"]]

# Create centroids
bld = buildings.copy()
bld["centroid"] = bld.geometry.centroid
bld_pts = bld.set_geometry("centroid")

# join centroid point in polygons
bld_pts_nta = gpd.sjoin(
    bld_pts,
    nta,
    how="left",
    predicate="within"
).drop(columns=["index_right"])

print("Building→NTA match rate:", bld_pts_nta["NTACode"].notna().mean())
bld_pts_nta.head(10)
# Out:
# Building→NTA match rate: 0.9999187441539651
#    name        bin  doitt_id  shape_area    base_bbl  objectid  constructi  \
# 0  None  4451699.0  321944.0  177.746094  4075320028  507357.0      1950.0
# 1  None  4558952.0  255026.0   34.742188  4105630045  137879.0      1930.0
# 2  None  3176483.0  759005.0  180.890625  3066450044  982953.0      1915.0
# 3  None  3393369.0  949392.0  106.035156  3038010128  244121.0      1997.0
# 4  None  2019299.0  353927.0  217.175781  2033800084  229537.0      1910.0
# 5  None  5052578.0  281098.0  240.582031  5036360058  246429.0      1960.0
# 6  None  3083803.0  419689.0   98.660156  3037200028  808886.0      1901.0
# 7  None  3100941.0  533049.0  588.093750  3046410004  370632.0      1931.0
# 8  None  2117607.0  458160.0  102.941406  2027640025   80512.0         NaN
# 9  None  5007740.0  649423.0  232.261719  5002870016  232182.0      1955.0
#
#    feature_co       geom_sourc  ground_ele  ...  mappluto_b  shape_leng  \
# 0      2100.0   Other (Manual)        93.0  ...  4075327501   59.004939
# 1      5110.0  Photogrammetric        72.0  ...  4105630045   24.548387
# 2      2100.0  Photogrammetric        18.0  ...  3066450044   61.475641
# 3      2100.0  Photogrammetric        32.0  ...  3038010128   43.732572
# 4      2100.0  Photogrammetric       197.0  ...  2033800084   63.268290
# 5      2100.0  Photogrammetric        44.0  ...  5036360058   69.030911
# 6      2100.0  Photogrammetric        44.0  ...  3037200028   43.248158
# 7      2100.0  Photogrammetric        34.0  ...  3046410004  107.406265
# 8      2100.0   Other (Manual)        25.0  ...  2027640025   47.428753
# 9      2100.0  Photogrammetric       220.0  ...  5002870016   63.023228
#
#                                             geometry geom_area_sqft  \
# 0  POLYGON ((1052359.953 214149.188, 1052400.668 ...    1096.759439
# 1  POLYGON ((1052764.922 201306.381, 1052748.182 ...     214.631781
# 2  POLYGON ((988769.316 159090.345, 988746.041 15...    1121.202926
# 3  POLYGON ((1012469.24 181742.107, 1012446.631 1...     656.015069
# 4  POLYGON ((1020199.824 267310.273, 1020201.035 ...    1334.183950
# 5  POLYGON ((952462.054 148588.137, 952441.334 14...    1492.459367
# 6  POLYGON ((1013026.308 184325.289, 1012989.42 1...     610.216125
# 7  POLYGON ((1004596.249 178502.966, 1004590.431 ...    3639.355961
# 8  POLYGON ((1016582.739 236282.258, 1016574.046 ...     634.043292
# 9  POLYGON ((954298.282 166992.865, 954260.635 16...    1438.693395
#
#   is_flooded  flooded_footprint_sqft                        centroid  NTACode  \
# 0      False                     0.0  POINT (1052386.895 214157.488)   QN1102
# 1      False                     0.0  POINT (1052753.726 201306.083)   QN1303
# 2      False                     0.0   POINT (988739.603 159096.157)   BK1103
# 3      False                     0.0   POINT (1012449.66 181747.497)   BK0503
# 4      False                     0.0  POINT (1020192.208 267285.288)   BX1203
# 5      False                     0.0   POINT (952434.647 148591.889)   SI0202
# 6      False                     0.0  POINT (1013006.311 184329.664)   BK0502
# 7      False                     0.0  POINT (1004613.443 178526.419)   BK1703
# 8      False                     0.0  POINT (1016585.368 236305.505)   BX0201
# 9      False                     0.0   POINT (954283.055 167005.521)   SI0104
#
#                                      NTAName       boroname
# 0                                    Bayside         Queens
# 1                             Queens Village         Queens
# 2                           Gravesend (West)       Brooklyn
# 3                     East New York-New Lots       Brooklyn
# 4                         Wakefield-Woodlawn          Bronx
# 5                     New Dorp-Midland Beach  Staten Island
# 6                      East New York (North)       Brooklyn
# 7                        East Flatbush-Rugby       Brooklyn
# 8                                Hunts Point          Bronx
# 9  West New Brighton-Silver Lake-Grymes Hill  Staten Island
#
# [10 rows x 24 columns]

# %%
import numpy as np

area_col = "geom_area_sqft"

nta_flood = (
    bld_pts_nta
    .groupby(["NTACode", "NTAName", "boroname"], dropna=False)
    .agg(
        building_count=("objectid", "size"),
        flooded_building_count=("is_flooded", "sum"),
        total_footprint_sqft=(area_col, "sum"),
        flooded_footprint_sqft=("flooded_footprint_sqft", "sum"),
    )
    .reset_index()
)

nta_flood["pct_buildings_flooded"] = np.where(
    nta_flood["building_count"] > 0,
    nta_flood["flooded_building_count"] / nta_flood["building_count"],
    np.nan
)

nta_flood["pct_footprint_flooded"] = np.where(
    nta_flood["total_footprint_sqft"] > 0,
    nta_flood["flooded_footprint_sqft"] / nta_flood["total_footprint_sqft"],
    np.nan
)

#15 most flooded
nta_flood.sort_values("pct_footprint_flooded", ascending=False).head(15)
# Out:
#     NTACode                                     NTAName       boroname  \
# 168  QN0271             Calvary & Mount Zion Cemeteries         Queens
# 161  QN0161                     Sunnyside Yards (North)         Queens
# 156  QN0102                   Old Astoria-Hallets Point         Queens
# 257  SI9592                                Miller Field  Staten Island
# 126  MN0401                        Chelsea-Hudson Yards      Manhattan
# 109  BX1161                     Hutchinson Metro Center          Bronx
# 130  MN0601        Stuyvesant Town-Peter Cooper Village      Manhattan
# 2    BK0103                          South Williamsburg       Brooklyn
# 224  QN1306      Springfield Gardens (South)-Brookville         Queens
# 182  QN0601                                   Rego Park         Queens
# 245  SI0201  Grasmere-Arrochar-South Beach-Dongan Hills  Staten Island
# 246  SI0202                      New Dorp-Midland Beach  Staten Island
# 213  QN1201                                     Jamaica         Queens
# 172  QN0401                                    Elmhurst         Queens
# 83   BX0502                                  Mount Hope          Bronx
#
#      building_count  flooded_building_count  total_footprint_sqft  \
# 168              21                      10          2.703237e+05
# 161              50                       9          1.356577e+06
# 156            1613                     385          3.268248e+06
# 257              27                       4          2.266161e+05
# 126            2075                     178          1.318783e+07
# 109             123                       7          1.833399e+06
# 130              80                      17          1.137596e+06
# 2              2294                     221          5.418461e+06
# 224            5514                     571          8.330722e+06
# 182            3726                      39          5.563253e+06
# 245           10074                    1080          1.240385e+07
# 246           10013                     934          1.113322e+07
# 213            7135                     396          1.467616e+07
# 172            9060                     331          1.384903e+07
# 83             1139                      71          4.451537e+06
#
#      flooded_footprint_sqft  pct_buildings_flooded  pct_footprint_flooded
# 168            1.959603e+05               0.476190               0.724910
# 161            4.198186e+05               0.180000               0.309469
# 156            8.412942e+05               0.238686               0.257414
# 257            5.766128e+04               0.148148               0.254445
# 126            2.619943e+06               0.085783               0.198664
# 109            3.455465e+05               0.056911               0.188473
# 130            2.023247e+05               0.212500               0.177853
# 2              9.007960e+05               0.096338               0.166246
# 224            1.122584e+06               0.103555               0.134752
# 182            7.207115e+05               0.010467               0.129549
# 245            1.506296e+06               0.107207               0.121438
# 246            1.325221e+06               0.093279               0.119033
# 213            1.714426e+06               0.055501               0.116817
# 172            1.369721e+06               0.036534               0.098904
# 83             4.330052e+05               0.062335               0.097271

# %%
nta_risk = nta_density.merge(
    nta_flood[["NTACode", "flooded_building_count", "flooded_footprint_sqft",
               "pct_buildings_flooded", "pct_footprint_flooded"]],
    on="NTACode",
    how="left"
)

nta_risk["risk_score"] = (
    nta_risk["built_area_ratio"].fillna(0) *
    nta_risk["pct_footprint_flooded"].fillna(0)
)

nta_risk.sort_values("risk_score", ascending=False).head(20)[
    ["NTACode", "NTAName", "boroname", "built_area_ratio", "pct_footprint_flooded", "risk_score"]
]
# Out:
#     NTACode                               NTAName   boroname  \
# 162  QN0161               Sunnyside Yards (North)     Queens
# 127  MN0401                  Chelsea-Hudson Yards  Manhattan
# 157  QN0102             Old Astoria-Hallets Point     Queens
# 2    BK0103                    South Williamsburg   Brooklyn
# 215  QN1201                               Jamaica     Queens
# 131  MN0601  Stuyvesant Town-Peter Cooper Village  Manhattan
# 183  QN0601                             Rego Park     Queens
# 84   BX0502                            Mount Hope      Bronx
# 173  QN0401                              Elmhurst     Queens
# 123  MN0203                          West Village  Manhattan
# 128  MN0402                        Hell's Kitchen  Manhattan
# 175  QN0501                               Maspeth     Queens
# 136  MN0701        Upper West Side-Lincoln Square  Manhattan
# 1    BK0102                          Williamsburg   Brooklyn
# 110  BX1161               Hutchinson Metro Center      Bronx
# 166  QN0202                             Sunnyside     Queens
# 158  QN0103                     Astoria (Central)     Queens
# 12   BK0402                       Bushwick (East)   Brooklyn
# 121  MN0201       SoHo-Little Italy-Hudson Square  Manhattan
# 16   BK0503                East New York-New Lots   Brooklyn
#
#      built_area_ratio  pct_footprint_flooded  risk_score
# 162          0.301443               0.309469    0.093287
# 127          0.444458               0.198664    0.088298
# 157          0.294674               0.257414    0.075853
# 2            0.356268               0.166246    0.059228
# 215          0.313400               0.116817    0.036610
# 131          0.205679               0.177853    0.036581
# 183          0.275499               0.129549    0.035691
# 84           0.351019               0.097271    0.034144
# 173          0.328939               0.098904    0.032533
# 123          0.416286               0.073578    0.030630
# 128          0.475031               0.062336    0.029612
# 175          0.334420               0.087927    0.029405
# 136          0.387470               0.075419    0.029223
# 1            0.359665               0.081145    0.029185
# 110          0.150508               0.188473    0.028367
# 166          0.303371               0.092197    0.027970
# 158          0.398614               0.069858    0.027847
# 12           0.348972               0.078451    0.027377
# 121          0.503253               0.053696    0.027023
# 16           0.322370               0.081997    0.026433

# %%
nta_risk.head(10)
# Out:
#   NTACode                              NTAName  boroname  \
# 0  BK0101                           Greenpoint  Brooklyn
# 1  BK0102                         Williamsburg  Brooklyn
# 2  BK0103                   South Williamsburg  Brooklyn
# 3  BK0104                    East Williamsburg  Brooklyn
# 4  BK0201                     Brooklyn Heights  Brooklyn
# 5  BK0202  Downtown Brooklyn-DUMBO-Boerum Hill  Brooklyn
# 6  BK0203                          Fort Greene  Brooklyn
# 7  BK0204                         Clinton Hill  Brooklyn
# 8  BK0261                   Brooklyn Navy Yard  Brooklyn
# 9  BK0301            Bedford-Stuyvesant (West)  Brooklyn
#
#                                             geometry  nta_area_sqft  \
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xdb\x01...   3.532174e+07
# 1  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x16\x01...   2.885280e+07
# 2  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00f\x00\x0...   1.520896e+07
# 3  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xa8\x02...   5.226747e+07
# 4  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00~\x00\x0...   9.982088e+06
# 5  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00*\x01\x0...   2.373148e+07
# 6  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x90\x00...   1.753369e+07
# 7  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00T\x00\x0...   1.456661e+07
# 8  b'\x01\x06\x00\x00\x00\x02\x00\x00\x00\x01\x03...   1.010687e+07
# 9  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00r\x00\x0...   3.690666e+07
#
#    nta_area_sqmi  building_count  total_footprint_sqft  median_building_sqft  \
# 0       1.266993          5147.0          1.340080e+07           1248.021588
# 1       1.034952          3646.0          1.037733e+07           1334.824761
# 2       0.545546          2294.0          5.418461e+06           1408.694795
# 3       1.874838          4939.0          1.745002e+07           1354.539352
# 4       0.358058          1492.0          3.913004e+06           1358.771123
# 5       0.851250          2000.0          8.258165e+06           1152.637541
# 6       0.628935          2130.0          5.244622e+06            994.499027
# 7       0.522505          2403.0          4.768999e+06            947.440147
# 8       0.362534           133.0          2.373427e+06           3920.259287
# 9       1.323844          7547.0          1.301454e+07            969.488934
#
#    built_area_ratio  buildings_per_sqmi  built_sqft_per_sqmi  \
# 0          0.379392         4062.373817         1.057685e+07
# 1          0.359665         3522.869432         1.002687e+07
# 2          0.356268         4204.958583         9.932172e+06
# 3          0.333860         2634.361536         9.307485e+06
# 4          0.392003         4166.921140         1.092840e+07
# 5          0.347984         2349.487226         9.701226e+06
# 6          0.299117         3386.680069         8.338900e+06
# 7          0.327392         4598.996563         9.127179e+06
# 8          0.234833          366.861926         6.546766e+06
# 9          0.352634         5700.821880         9.830872e+06
#
#    flooded_building_count  flooded_footprint_sqft  pct_buildings_flooded  \
# 0                   174.0           681959.369194               0.033813
# 1                   106.0           842069.864516               0.029073
# 2                   221.0           900796.021973               0.096338
# 3                    91.0           736213.686240               0.018436
# 4                     0.0                0.000000               0.000000
# 5                     7.0           107214.617391               0.003502
# 6                    11.0           109686.611062               0.005164
# 7                     4.0             7765.822371               0.001665
# 8                     0.0                0.000000               0.000000
# 9                   243.0           825168.625932               0.032198
#
#    pct_footprint_flooded  risk_score
# 0               0.050902    0.019312
# 1               0.081145    0.029185
# 2               0.166246    0.059228
# 3               0.042365    0.014144
# 4               0.000000    0.000000
# 5               0.012984    0.004518
# 6               0.020914    0.006256
# 7               0.001628    0.000533
# 8               0.000000    0.000000
# 9               0.063404    0.022358

# %%
bld_pts_nta.to_parquet(
    os.path.join(DATA_PROCESSED, "building_current_2263_with_nta.parquet"),
    index=False
)

# %%
buildings.head(10)
# Out:
#    name        bin  doitt_id  shape_area    base_bbl  objectid  constructi  \
# 0  None  4451699.0  321944.0  177.746094  4075320028  507357.0      1950.0
# 1  None  4558952.0  255026.0   34.742188  4105630045  137879.0      1930.0
# 2  None  3176483.0  759005.0  180.890625  3066450044  982953.0      1915.0
# 3  None  3393369.0  949392.0  106.035156  3038010128  244121.0      1997.0
# 4  None  2019299.0  353927.0  217.175781  2033800084  229537.0      1910.0
# 5  None  5052578.0  281098.0  240.582031  5036360058  246429.0      1960.0
# 6  None  3083803.0  419689.0   98.660156  3037200028  808886.0      1901.0
# 7  None  3100941.0  533049.0  588.093750  3046410004  370632.0      1931.0
# 8  None  2117607.0  458160.0  102.941406  2027640025   80512.0         NaN
# 9  None  5007740.0  649423.0  232.261719  5002870016  232182.0      1955.0
#
#    feature_co       geom_sourc  ground_ele  height_roo date_last_  \
# 0      2100.0   Other (Manual)        93.0   27.000000 2017-08-22
# 1      5110.0  Photogrammetric        72.0   13.060000 2017-08-17
# 2      2100.0  Photogrammetric        18.0   36.761589 2017-08-22
# 3      2100.0  Photogrammetric        32.0   21.950000 2017-08-22
# 4      2100.0  Photogrammetric       197.0   33.490000 2017-08-22
# 5      2100.0  Photogrammetric        44.0   21.130000 2017-08-22
# 6      2100.0  Photogrammetric        44.0   30.110000 2017-08-22
# 7      2100.0  Photogrammetric        34.0   14.310000 2017-08-22
# 8      2100.0   Other (Manual)        25.0   11.000000 2017-08-10
# 9      2100.0  Photogrammetric       220.0   17.960000 2017-08-22
#
#      time_last_   last_statu  mappluto_b  shape_leng  \
# 0  19:18:38.000  Constructed  4075327501   59.004939
# 1  16:20:43.000  Constructed  4105630045   24.548387
# 2  15:37:34.000  Constructed  3066450044   61.475641
# 3  15:31:10.000  Constructed  3038010128   43.732572
# 4  18:57:18.000  Constructed  2033800084   63.268290
# 5  18:56:39.000  Constructed  5036360058   69.030911
# 6  15:51:01.000  Constructed  3037200028   43.248158
# 7  15:46:44.000  Constructed  3046410004  107.406265
# 8  15:05:25.000  Constructed  2027640025   47.428753
# 9  17:36:42.000  Constructed  5002870016   63.023228
#
#                                             geometry  geom_area_sqft  \
# 0  POLYGON ((1052359.953 214149.188, 1052400.668 ...     1096.759439
# 1  POLYGON ((1052764.922 201306.381, 1052748.182 ...      214.631781
# 2  POLYGON ((988769.316 159090.345, 988746.041 15...     1121.202926
# 3  POLYGON ((1012469.24 181742.107, 1012446.631 1...      656.015069
# 4  POLYGON ((1020199.824 267310.273, 1020201.035 ...     1334.183950
# 5  POLYGON ((952462.054 148588.137, 952441.334 14...     1492.459367
# 6  POLYGON ((1013026.308 184325.289, 1012989.42 1...      610.216125
# 7  POLYGON ((1004596.249 178502.966, 1004590.431 ...     3639.355961
# 8  POLYGON ((1016582.739 236282.258, 1016574.046 ...      634.043292
# 9  POLYGON ((954298.282 166992.865, 954260.635 16...     1438.693395
#
#    is_flooded  flooded_footprint_sqft
# 0       False                     0.0
# 1       False                     0.0
# 2       False                     0.0
# 3       False                     0.0
# 4       False                     0.0
# 5       False                     0.0
# 6       False                     0.0
# 7       False                     0.0
# 8       False                     0.0
# 9       False                     0.0

# %%
import pandas as pd

# constructi is your "year built" field (float) — convert to nullable Int
bld_pts_nta = bld_pts_nta.copy()

bld_pts_nta["construction_year"] = (
    pd.to_numeric(bld_pts_nta["constructi"], errors="coerce")
    .round()
    .astype("Int64")
)

# define cohorts (change thresholds if you want)
bld_pts_nta["built_last_10yrs"] = bld_pts_nta["construction_year"] >= 2015
bld_pts_nta["built_last_20yrs"] = bld_pts_nta["construction_year"] >= 2005

# quick QA
bld_pts_nta[["constructi","construction_year","built_last_10yrs","built_last_20yrs"]].head(10)
# Out:
#    constructi  construction_year  built_last_10yrs  built_last_20yrs
# 0      1950.0               1950             False             False
# 1      1930.0               1930             False             False
# 2      1915.0               1915             False             False
# 3      1997.0               1997             False             False
# 4      1910.0               1910             False             False
# 5      1960.0               1960             False             False
# 6      1901.0               1901             False             False
# 7      1931.0               1931             False             False
# 8         NaN               <NA>              <NA>              <NA>
# 9      1955.0               1955             False             False

# %%
bld_pts_nta["construction_year"].isna().mean()
# Out:
# np.float64(0.009344422294018738)

# %%
bld_pts_nta.head(10)
# Out:
#    name        bin  doitt_id  shape_area    base_bbl  objectid  constructi  \
# 0  None  4451699.0  321944.0  177.746094  4075320028  507357.0      1950.0
# 1  None  4558952.0  255026.0   34.742188  4105630045  137879.0      1930.0
# 2  None  3176483.0  759005.0  180.890625  3066450044  982953.0      1915.0
# 3  None  3393369.0  949392.0  106.035156  3038010128  244121.0      1997.0
# 4  None  2019299.0  353927.0  217.175781  2033800084  229537.0      1910.0
# 5  None  5052578.0  281098.0  240.582031  5036360058  246429.0      1960.0
# 6  None  3083803.0  419689.0   98.660156  3037200028  808886.0      1901.0
# 7  None  3100941.0  533049.0  588.093750  3046410004  370632.0      1931.0
# 8  None  2117607.0  458160.0  102.941406  2027640025   80512.0         NaN
# 9  None  5007740.0  649423.0  232.261719  5002870016  232182.0      1955.0
#
#    feature_co       geom_sourc  ground_ele  ...  geom_area_sqft is_flooded  \
# 0      2100.0   Other (Manual)        93.0  ...     1096.759439      False
# 1      5110.0  Photogrammetric        72.0  ...      214.631781      False
# 2      2100.0  Photogrammetric        18.0  ...     1121.202926      False
# 3      2100.0  Photogrammetric        32.0  ...      656.015069      False
# 4      2100.0  Photogrammetric       197.0  ...     1334.183950      False
# 5      2100.0  Photogrammetric        44.0  ...     1492.459367      False
# 6      2100.0  Photogrammetric        44.0  ...      610.216125      False
# 7      2100.0  Photogrammetric        34.0  ...     3639.355961      False
# 8      2100.0   Other (Manual)        25.0  ...      634.043292      False
# 9      2100.0  Photogrammetric       220.0  ...     1438.693395      False
#
#   flooded_footprint_sqft                        centroid NTACode  \
# 0                    0.0  POINT (1052386.895 214157.488)  QN1102
# 1                    0.0  POINT (1052753.726 201306.083)  QN1303
# 2                    0.0   POINT (988739.603 159096.157)  BK1103
# 3                    0.0   POINT (1012449.66 181747.497)  BK0503
# 4                    0.0  POINT (1020192.208 267285.288)  BX1203
# 5                    0.0   POINT (952434.647 148591.889)  SI0202
# 6                    0.0  POINT (1013006.311 184329.664)  BK0502
# 7                    0.0  POINT (1004613.443 178526.419)  BK1703
# 8                    0.0  POINT (1016585.368 236305.505)  BX0201
# 9                    0.0   POINT (954283.055 167005.521)  SI0104
#
#                                      NTAName       boroname  \
# 0                                    Bayside         Queens
# 1                             Queens Village         Queens
# 2                           Gravesend (West)       Brooklyn
# 3                     East New York-New Lots       Brooklyn
# 4                         Wakefield-Woodlawn          Bronx
# 5                     New Dorp-Midland Beach  Staten Island
# 6                      East New York (North)       Brooklyn
# 7                        East Flatbush-Rugby       Brooklyn
# 8                                Hunts Point          Bronx
# 9  West New Brighton-Silver Lake-Grymes Hill  Staten Island
#
#    construction_year  built_last_10yrs  built_last_20yrs
# 0               1950             False             False
# 1               1930             False             False
# 2               1915             False             False
# 3               1997             False             False
# 4               1910             False             False
# 5               1960             False             False
# 6               1901             False             False
# 7               1931             False             False
# 8               <NA>              <NA>              <NA>
# 9               1955             False             False
#
# [10 rows x 27 columns]

# %%
nta_attrs = bld_pts_nta[[
    "objectid",
    "NTACode",
    "NTAName",
    "boroname",
    "construction_year",
    "built_last_10yrs",
    "built_last_20yrs",
]].copy()

buildings_enriched = buildings.merge(
    nta_attrs,
    on="objectid",
    how="left",
    validate="1:1"
)

# %%
buildings_enriched.geometry.geom_type.value_counts()
buildings_enriched[["NTACode", "NTAName", "boroname"]].head()
# Out:
#   NTACode                 NTAName  boroname
# 0  QN1102                 Bayside    Queens
# 1  QN1303          Queens Village    Queens
# 2  BK1103        Gravesend (West)  Brooklyn
# 3  BK0503  East New York-New Lots  Brooklyn
# 4  BX1203      Wakefield-Woodlawn     Bronx

# %%
viz_buildings = buildings_enriched[[
    "objectid",
    "geometry",
    "NTACode",
    "NTAName",
    "boroname",
    "geom_area_sqft",
    "is_flooded",
    "flooded_footprint_sqft",
    "construction_year",
    "built_last_10yrs",
    "built_last_20yrs",
]].copy()

viz_buildings.to_parquet(
    os.path.join(DATA_PROCESSED, "buildings_viz.parquet"),
    index=False
)

print("Saved buildings_viz.parquet:", viz_buildings.shape)
# Out:
# Saved buildings_viz.parquet: (1082999, 11)

# %%
import numpy as np

b = buildings_enriched.copy()
area_col = "geom_area_sqft"

# totals
nta_flood = (
    b.groupby(["NTACode", "NTAName", "boroname"], dropna=False)
     .agg(
         building_count=("objectid", "size"),
         flooded_building_count=("is_flooded", "sum"),
         total_footprint_sqft=(area_col, "sum"),
         flooded_footprint_sqft=("flooded_footprint_sqft", "sum"),
     )
     .reset_index()
)

nta_flood["pct_buildings_flooded"] = np.where(
    nta_flood["building_count"] > 0,
    nta_flood["flooded_building_count"] / nta_flood["building_count"],
    np.nan
)

nta_flood["pct_footprint_flooded"] = np.where(
    nta_flood["total_footprint_sqft"] > 0,
    nta_flood["flooded_footprint_sqft"] / nta_flood["total_footprint_sqft"],
    np.nan
)

nta_flood.head()
# Out:
#   NTACode             NTAName  boroname  building_count  \
# 0  BK0101          Greenpoint  Brooklyn            5146
# 1  BK0102        Williamsburg  Brooklyn            3646
# 2  BK0103  South Williamsburg  Brooklyn            2294
# 3  BK0104   East Williamsburg  Brooklyn            4936
# 4  BK0201    Brooklyn Heights  Brooklyn            1490
#
#    flooded_building_count  total_footprint_sqft  flooded_footprint_sqft  \
# 0                     174          1.339760e+07           681959.369194
# 1                     106          1.037733e+07           842069.864516
# 2                     221          5.418461e+06           900796.021973
# 3                      91          1.737771e+07           736213.686240
# 4                       0          3.907187e+06                0.000000
#
#    pct_buildings_flooded  pct_footprint_flooded
# 0               0.033813               0.050902
# 1               0.029073               0.081145
# 2               0.096338               0.166246
# 3               0.018436               0.042365
# 4               0.000000               0.000000

# %%
def flood_metrics_for_subset(df, label):
    g = (df.groupby(["NTACode", "NTAName", "boroname"], dropna=False)
           .agg(
               bld_count=("objectid", "size"),
               bld_flooded=("is_flooded", "sum"),
               sqft_total=("geom_area_sqft", "sum"),
               sqft_flooded=("flooded_footprint_sqft", "sum"),
           )
           .reset_index())
    g[f"pct_bld_flooded_{label}"] = np.where(g["bld_count"]>0, g["bld_flooded"]/g["bld_count"], np.nan)
    g[f"pct_sqft_flooded_{label}"] = np.where(g["sqft_total"]>0, g["sqft_flooded"]/g["sqft_total"], np.nan)
    return g[["NTACode","NTAName","boroname", f"pct_bld_flooded_{label}", f"pct_sqft_flooded_{label}"]]

recent10 = flood_metrics_for_subset(b[b["built_last_10yrs"] == True], "last10")
recent20 = flood_metrics_for_subset(b[b["built_last_20yrs"] == True], "last20")

# %%
nta_viz = (
    nta_density
      .merge(
          nta_flood[[
              "NTACode","pct_buildings_flooded","pct_footprint_flooded",
              "flooded_building_count","flooded_footprint_sqft"
          ]],
          on="NTACode",
          how="left",
          validate="1:1"
      )
      .merge(recent10[["NTACode","pct_bld_flooded_last10","pct_sqft_flooded_last10"]],
             on="NTACode", how="left", validate="1:1")
      .merge(recent20[["NTACode","pct_bld_flooded_last20","pct_sqft_flooded_last20"]],
             on="NTACode", how="left", validate="1:1")
)

nta_viz["risk_score"] = nta_viz["built_area_ratio"] * nta_viz["pct_footprint_flooded"]

nta_viz.sort_values("risk_score", ascending=False).head(10)
# Out:
#     NTACode                               NTAName   boroname  \
# 162  QN0161               Sunnyside Yards (North)     Queens
# 127  MN0401                  Chelsea-Hudson Yards  Manhattan
# 157  QN0102             Old Astoria-Hallets Point     Queens
# 2    BK0103                    South Williamsburg   Brooklyn
# 215  QN1201                               Jamaica     Queens
# 131  MN0601  Stuyvesant Town-Peter Cooper Village  Manhattan
# 183  QN0601                             Rego Park     Queens
# 84   BX0502                            Mount Hope      Bronx
# 173  QN0401                              Elmhurst     Queens
# 123  MN0203                          West Village  Manhattan
#
#                                               geometry  nta_area_sqft  \
# 162  b'\x01\x03\x00\x00\x00\x01\x00\x00\x002\x00\x0...   4.500282e+06
# 127  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00t\x01\x0...   2.967175e+07
# 157  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00U\x00\x0...   1.109107e+07
# 2    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00f\x00\x0...   1.520896e+07
# 215  b'\x01\x03\x00\x00\x00\x01\x00\x00\x007\x01\x0...   4.682885e+07
# 131  b'\x01\x06\x00\x00\x00\x02\x00\x00\x00\x01\x03...   5.575562e+06
# 183  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x80\x00...   2.019335e+07
# 84   b'\x01\x03\x00\x00\x00\x01\x00\x00\x00Q\x00\x0...   1.268177e+07
# 173  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xca\x00...   4.210214e+07
# 123  b'\x01\x03\x00\x00\x00\x02\x00\x00\x00\xa3\x00...   1.441686e+07
#
#      nta_area_sqmi  building_count  total_footprint_sqft  \
# 162       0.161425            50.0          1.356577e+06
# 127       1.064328          2075.0          1.318783e+07
# 157       0.397837          1613.0          3.268248e+06
# 2         0.545546          2294.0          5.418461e+06
# 215       1.679754          7135.0          1.467616e+07
# 131       0.199996            82.0          1.146778e+06
# 183       0.724337          3726.0          5.563253e+06
# 84        0.454896          1139.0          4.451537e+06
# 173       1.510207          9060.0          1.384903e+07
# 123       0.517134          2286.0          6.001532e+06
#
#      median_building_sqft  built_area_ratio  ...  built_sqft_per_sqmi  \
# 162          13113.628467          0.301443  ...         8.403740e+06
# 127           2007.850335          0.444458  ...         1.239076e+07
# 157           1023.525919          0.294674  ...         8.215037e+06
# 2             1408.694795          0.356268  ...         9.932172e+06
# 215            946.716756          0.313400  ...         8.737091e+06
# 131           9269.694112          0.205679  ...         5.734009e+06
# 183            816.253716          0.275499  ...         7.680477e+06
# 84            1711.109360          0.351019  ...         9.785840e+06
# 173            989.628040          0.328939  ...         9.170291e+06
# 123           1266.852671          0.416286  ...         1.160538e+07
#
#      pct_buildings_flooded  pct_footprint_flooded  flooded_building_count  \
# 162               0.180000               0.309469                     9.0
# 127               0.085783               0.198664                   178.0
# 157               0.238686               0.257414                   385.0
# 2                 0.096338               0.166246                   221.0
# 215               0.055501               0.116817                   396.0
# 131               0.212500               0.177853                    17.0
# 183               0.010467               0.129549                    39.0
# 84                0.062335               0.097271                    71.0
# 173               0.036534               0.098904                   331.0
# 123               0.037183               0.073578                    85.0
#
#      flooded_footprint_sqft  pct_bld_flooded_last10  pct_sqft_flooded_last10  \
# 162            4.198186e+05                0.000000                 0.000000
# 127            2.619943e+06                0.240000                 0.278196
# 157            8.412942e+05                0.281690                 0.282242
# 2              9.007960e+05                0.380435                 0.599015
# 215            1.714426e+06                0.055556                 0.090400
# 131            2.023247e+05                0.000000                 0.000000
# 183            7.207115e+05                0.130435                 0.722847
# 84             4.330052e+05                0.061224                 0.194435
# 173            1.369721e+06                0.123288                 0.180947
# 123            4.415818e+05                0.095238                 0.084907
#
#      pct_bld_flooded_last20  pct_sqft_flooded_last20  risk_score
# 162                0.000000                 0.000000    0.093287
# 127                0.232143                 0.291166    0.088298
# 157                0.299270                 0.299446    0.075853
# 2                  0.377778                 0.541016    0.059228
# 215                0.051630                 0.124530    0.036610
# 131                0.000000                 0.000000    0.036581
# 183                0.081633                 0.481945    0.035691
# 84                 0.053333                 0.171443    0.034144
# 173                0.077922                 0.152092    0.032533
# 123                0.117647                 0.179436    0.030630
#
# [10 rows x 21 columns]

# %%
nta_viz.to_parquet(
    os.path.join(DATA_PROCESSED, "nta_viz.parquet"),
    index=False
)

print("Saved nta_viz.parquet:", nta_viz.shape)
# Out:
# Saved nta_viz.parquet: (262, 21)
